# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/root/notebooks/project/Self-Attention-GAN/sagan'

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from dataset import *
from pprint import pprint

# %%
config = {
    'dataset': 'Lsun_church',
    'data_path': '/root/notebooks/data/church_outdoor_train_lmdb/',
    'data_size': 6400,
    'use_image_generator': False,
    'batch_size': 64,
    'num_sample': 16
}

# %%
ds, config = get_dataset_and_info(config)
# Out:
# Load: 6400 of 126227 records

# %%
for i,d in enumerate(ds):
    if i == 1000:
        break
    if i%100 == 0:
        print(i, d[0].shape, d[1].shape)
# Out:
# 0 (64, 64, 64, 3) (64,)

# %%
# ds = iter(ds)
images, labels = next(ds)
images = np.uint8(images*127.5+128).clip(0,255)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e211c62e42ca> in <module>
#       1 # ds = iter(ds)
# ----> 2 images, labels = next(ds)
#       3 images = np.uint8(images*127.5+128).clip(0,255)
#
# TypeError: 'BatchDataset' object is not an iterator

# %%
images.max(), images.min(), images.mean(), images.std()
# Out:
# (255, 0, 103.57380930582683, 70.2876177369406)

# %%
for img in images:
    plt.imshow(img)
    plt.show()

# %%
labels.shape, labels.dtype
# Out:
# ((64,), dtype('float32'))
